# %% [markdown]
# # Segment Association Rules
#
# Explain cluster behavior using derived segment-specific association rules.
#
# This notebook is a cleaned and renamed version of the original analysis notebook.

# %% [markdown]
# ## Notebook Guide
# This notebook explains each customer segment with compact association rules built from binned customer metrics, then translates those rules into clearer business language.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd()
DATA_DIR = PROJECT_ROOT / 'dataset'
GENERATED_DIR = PROJECT_ROOT / 'generated'
FIGURES_DIR = PROJECT_ROOT / 'figures'

GENERATED_DIR.mkdir(exist_ok=True)
FIGURES_DIR.mkdir(exist_ok=True)

print(f'Project root: {PROJECT_ROOT}')
print(f'Dataset dir: {DATA_DIR}')
print(f'Generated dir: {GENERATED_DIR}')
print(f'Figures dir: {FIGURES_DIR}')
# Out:
# Project root: /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis
# Dataset dir: /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/dataset
# Generated dir: /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated
# Figures dir: /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/figures

# %%
import pandas as pd
import numpy as np
from itertools import combinations

# %% [markdown]
# ## Step 0) Parameter configuration
# Define the input dataset, candidate features, and rule-quality thresholds used throughout the notebook.

# %%
# =========================
# Step 0) Parameter configuration
# =========================
PATH = GENERATED_DIR / "customers_with_segments.csv"

FEATURES = [
    "MT_TTC_NET_total_spend",
    "CD_TICKET_UNIQUE_total_transactions",
    "avg_basket_value",
    "avg_items_per_basket",
    "product_diversity_score",
    "promo_percentage",
    "QTY_PROMO_STORE_store_promo_qty",
    "QTY_PROMO_NAT_nat_promo_qty",
    "ID_MAG_TIERS_stores_visited",
    "store_loyalty_score",
    "recency_days",
    "avg_days_between_visits",
]
TARGET = "Cluster"

# The threshold 
MAX_ANT_LEN = 2          # maximum antecedent（start with 2, easy and fast to explain）
MIN_SUPPORT_JOINT = 0.01 # support(A ∧ cluster) >= 1%
MIN_CONFIDENCE = 0.50
MIN_LIFT = 1.30
TOP_N_PER_CLUSTER = 10

# %% [markdown]
# ## Step 1) Read and validate the input data
# Load the segment table and verify that every required field is available.

# %%
# =========================
# Step 1) Read and validate the input data
# =========================
df = pd.read_csv(PATH)

print("Shape:", df.shape)
print("Columns:", len(df.columns))

missing_cols = [c for c in FEATURES + [TARGET] if c not in df.columns]
if missing_cols:
    raise ValueError(f"missing cols：{missing_cols}")

df_sel = df[FEATURES + [TARGET]].copy()

# Ensure every rule-mining feature is numeric before binning.
for c in FEATURES:
    df_sel[c] = pd.to_numeric(df_sel[c], errors="coerce")
df_sel[TARGET] = df_sel[TARGET].astype(int)

print("\nMissing values per selected column (top 10):")
print(df_sel.isna().sum().sort_values(ascending=False).head(10))

print("\nCluster distribution:")
print(df_sel[TARGET].value_counts(normalize=True).sort_index().round(4))
# Out:
# Shape: (121112, 28)
# Columns: 28
#
# Missing values per selected column (top 10):
# MT_TTC_NET_total_spend                 0
# CD_TICKET_UNIQUE_total_transactions    0
# avg_basket_value                       0
# avg_items_per_basket                   0
# product_diversity_score                0
# promo_percentage                       0
# QTY_PROMO_STORE_store_promo_qty        0
# QTY_PROMO_NAT_nat_promo_qty            0
# ID_MAG_TIERS_stores_visited            0
# store_loyalty_score                    0
# dtype: int64
#
# Cluster distribution:
# Cluster
# 0    0.4671
# 1    0.1415
# 2    0.0596
# 3    0.3318
# Name: proportion, dtype: float64

# %% [markdown]
# ## Step 2) Bin numeric features into low / medium / high labels
# Convert continuous metrics into categorical descriptors that are easier to explain in rules.

# %%
# =========================
# Step 2) Bin numeric features into low / medium / high labels
# =========================
def bin_3(s: pd.Series) -> pd.Series:

    s = s.astype(float)
    try:
        b = pd.qcut(s, q=3, labels=["low", "mid", "high"], duplicates="drop")
        # Use quantile bins when possible, then fall back to manual thresholds if necessary.
        if hasattr(b, "cat") and len(b.cat.categories) == 3:
            return b.astype(str)
    except Exception:
        pass

    # Fallback: split at the 33rd and 67th percentiles when qcut cannot create three bins.
    t1, t2 = s.quantile(1/3), s.quantile(2/3)
    lab = np.where(s <= t1, "low", np.where(s <= t2, "mid", "high"))
    return pd.Series(lab, index=s.index, dtype="object")


# Convert each feature value into a labelled item such as `avg_basket_value=high`.
binned = pd.DataFrame({
    c: bin_3(df_sel[c]).map(lambda x, c=c: f"{c}={x}")
    for c in FEATURES
})
binned["cluster_item"] = df_sel[TARGET].map(lambda k: f"cluster={k}")

print("\nBin distribution check (each feature shows top 3 bins):")
for c in FEATURES[:6]:
    print(f"- {c}:")
    print(binned[c].value_counts(normalize=True).head(3).round(4).to_string())
print("...")
# Out:
# Bin distribution check (each feature shows top 3 bins):
# - MT_TTC_NET_total_spend:
# MT_TTC_NET_total_spend
# MT_TTC_NET_total_spend=low     0.3334
# MT_TTC_NET_total_spend=high    0.3333
# MT_TTC_NET_total_spend=mid     0.3333
# - CD_TICKET_UNIQUE_total_transactions:
# CD_TICKET_UNIQUE_total_transactions
# CD_TICKET_UNIQUE_total_transactions=low     0.732
# CD_TICKET_UNIQUE_total_transactions=high    0.268
# - avg_basket_value:
# avg_basket_value
# avg_basket_value=low     0.3335
# avg_basket_value=mid     0.3333
# avg_basket_value=high    0.3332
# - avg_items_per_basket:
# avg_items_per_basket
# avg_items_per_basket=low     0.3333
# avg_items_per_basket=high    0.3333
# avg_items_per_basket=mid     0.3333
# - product_diversity_score:
# product_diversity_score
# product_diversity_score=low     0.3377
# product_diversity_score=mid     0.3342
# product_diversity_score=high    0.3282
# - promo_percentage:
# promo_percentage
# promo_percentage=low     0.6887
# promo_percentage=high    0.3113
# ...

# %% [markdown]
# ## Step 3) Encode the labelled rows as bitsets
# Represent each customer profile efficiently so rule mining can be computed quickly.

# %%
# =========================
# Step 3) Encode the labelled rows as bitsets
# =========================
items = sorted(pd.unique(binned[FEATURES].values.ravel()))
print("\nTotal unique items:", len(items))

# Store each unique label as one bit inside a compact unsigned integer.
if len(items) > 63:
    raise ValueError(
        f"items={len(items)} is too large (>63); reduce the feature list or switch to a wider encoding strategy"
    )

item_to_bit = {it: i for i, it in enumerate(items)}
N = len(binned)
bits = np.zeros(N, dtype=np.uint64)
one = np.uint64(1)

for col in FEATURES:
    idx = binned[col].map(item_to_bit).to_numpy(dtype=np.uint64)
    bits |= (one << idx)

clusters = sorted(df_sel[TARGET].unique())
cluster_masks = {k: (df_sel[TARGET].to_numpy() == k) for k in clusters}
p_cluster = {k: cluster_masks[k].mean() for k in clusters}
# Out:
# Total unique items: 31

# %% [markdown]
# ## Step 4) Mine candidate rules and score them
# Enumerate short antecedents and retain only the rules that meet the support, confidence, and lift thresholds.

# %%
# =========================
# Step 4) Mine candidate rules and score them
# =========================
def mine_rules(max_len=2, min_support_joint=0.01, min_conf=0.5, min_lift=1.3):
    rules = []
    item_bits = [(it, (np.uint64(1) << np.uint64(i))) for it, i in item_to_bit.items()]
    item_bits = sorted(item_bits, key=lambda x: x[0])

    for r in range(1, max_len + 1):
        for combo in combinations(item_bits, r):
            ant_items = [c[0] for c in combo]
            ant_bits = np.uint64(0)
            for _, b in combo:
                ant_bits |= b

            presence = (bits & ant_bits) == ant_bits  # Check whether every item in the antecedent is present for the row.
            suppA = presence.mean()

            if suppA < min_support_joint:
                continue

            for k in clusters:
                supp_joint = (presence & cluster_masks[k]).mean()  # Joint support of the antecedent and the target cluster.
                if supp_joint < min_support_joint:
                    continue

                conf = supp_joint / suppA
                if conf < min_conf:
                    continue

                lift = conf / p_cluster[k]
                if lift < min_lift:
                    continue

                rules.append({
                    "cluster": k,
                    "antecedent": " & ".join(ant_items),
                    "consequent": f"cluster={k}",
                    "support": supp_joint,
                    "confidence": conf,
                    "lift": lift,
                    "support_antecedent": suppA,
                })

    return pd.DataFrame(rules)

rules_df = mine_rules(
    max_len=MAX_ANT_LEN,
    min_support_joint=MIN_SUPPORT_JOINT,
    min_conf=MIN_CONFIDENCE,
    min_lift=MIN_LIFT
)

print("\nTotal rules found:", len(rules_df))
if len(rules_df) == 0:
    print("No rules were found: please relax the thresholds (e.g., lower MIN_SUPPORT_JOINT, MIN_CONFIDENCE, or MIN_LIFT).")
# Out:
# Total rules found: 203

# %% [markdown]
# ## Step 5) Save the top rules for each cluster
# Keep the strongest rules per cluster and write them to disk for later reporting.

# %%
# Step 5) Save the top rules for each cluster
# =========================
out = []
for k in clusters:
    sub = (rules_df[rules_df["cluster"] == k]
           .sort_values(["lift", "confidence", "support"], ascending=[False, False, False])
           .head(TOP_N_PER_CLUSTER))
    out.append(sub)

result = pd.concat(out, ignore_index=True) if out else rules_df

print("\nTop rules per cluster (preview):")
cols_show = ["cluster", "antecedent", "support", "confidence", "lift"]
print(result[cols_show].to_string(index=False))

# Persist the ranked cluster-level explanation rules.
result.to_csv(GENERATED_DIR / "cluster_explain_rules_top.csv", index=False)
print("\nSaved: cluster_explain_rules_top.csv")
# Out:
# Top rules per cluster (preview):
#  cluster                                                                     antecedent  support  confidence      lift
#        0                                  MT_TTC_NET_total_spend=low & recency_days=low 0.076103    0.942916  2.018567
#        0                                     recency_days=low & store_loyalty_score=mid 0.097133    0.859125  1.839190
#        0                     CD_TICKET_UNIQUE_total_transactions=low & recency_days=low 0.170933    0.842127  1.802801
#        0                                 avg_days_between_visits=low & recency_days=low 0.172171    0.838676  1.795413
#        0                  ID_MAG_TIERS_stores_visited=high & MT_TTC_NET_total_spend=mid 0.016580    0.830782  1.778514
#        0                                    avg_items_per_basket=low & recency_days=low 0.084426    0.830693  1.778324
#        0                                        avg_basket_value=low & recency_days=low 0.076879    0.828676  1.774005
#        0                                 product_diversity_score=mid & recency_days=low 0.089620    0.827602  1.771707
#        0                           MT_TTC_NET_total_spend=low & store_loyalty_score=low 0.016109    0.819748  1.754893
#        0                   ID_MAG_TIERS_stores_visited=mid & MT_TTC_NET_total_spend=low 0.015349    0.817143  1.749316
#        1                           avg_basket_value=high & avg_days_between_visits=high 0.062760    0.757373  5.352571
#        1               CD_TICKET_UNIQUE_total_transactions=high & avg_basket_value=high 0.063693    0.754204  5.330173
#        1                ID_MAG_TIERS_stores_visited=high & avg_days_between_visits=high 0.048781    0.737026  5.208770
#        1    CD_TICKET_UNIQUE_total_transactions=high & ID_MAG_TIERS_stores_visited=high 0.049136    0.734601  5.191630
#        1                       avg_days_between_visits=high & avg_items_per_basket=high 0.062042    0.719801  5.087034
#        1           CD_TICKET_UNIQUE_total_transactions=high & avg_items_per_basket=high 0.062843    0.717342  5.069659
#        1                 ID_MAG_TIERS_stores_visited=high & MT_TTC_NET_total_spend=high 0.068523    0.667605  4.718154
#        1                            ID_MAG_TIERS_stores_visited=high & recency_days=low 0.036404    0.655808  4.634783
#        1                   ID_MAG_TIERS_stores_visited=high & avg_items_per_basket=high 0.051589    0.642204  4.538634
#        1            ID_MAG_TIERS_stores_visited=high & QTY_PROMO_NAT_nat_promo_qty=high 0.040359    0.635465  4.491013
#        2                       QTY_PROMO_STORE_store_promo_qty=high & recency_days=high 0.033853    0.849917 14.268805
#        2 CD_TICKET_UNIQUE_total_transactions=low & QTY_PROMO_STORE_store_promo_qty=high 0.031384    0.699871 11.749763
#        2             QTY_PROMO_STORE_store_promo_qty=high & avg_days_between_visits=low 0.031690    0.698962 11.734499
#        2              MT_TTC_NET_total_spend=mid & QTY_PROMO_STORE_store_promo_qty=high 0.014119    0.652174 10.949000
#        2         ID_MAG_TIERS_stores_visited=low & QTY_PROMO_STORE_store_promo_qty=high 0.019585    0.626519 10.518289
#        2             QTY_PROMO_STORE_store_promo_qty=high & product_diversity_score=mid 0.013178    0.616692 10.353320
#        2                 QTY_PROMO_STORE_store_promo_qty=high & store_loyalty_score=mid 0.014309    0.592276  9.943408
#        2        QTY_PROMO_NAT_nat_promo_qty=high & QTY_PROMO_STORE_store_promo_qty=high 0.026191    0.550790  9.246921
#        2                   QTY_PROMO_STORE_store_promo_qty=high & avg_basket_value=high 0.026521    0.513345  8.618276
#        2         ID_MAG_TIERS_stores_visited=mid & QTY_PROMO_STORE_store_promo_qty=high 0.014697    0.505395  8.484802
#        3                               avg_basket_value=high & store_loyalty_score=high 0.024259    0.894641  2.696188
#        3                                   recency_days=high & store_loyalty_score=high 0.094285    0.882117  2.658445
#        3                           avg_items_per_basket=high & store_loyalty_score=high 0.033795    0.864597  2.605644
#        3            CD_TICKET_UNIQUE_total_transactions=high & store_loyalty_score=high 0.027644    0.864446  2.605191
#        3                        avg_days_between_visits=high & store_loyalty_score=high 0.026323    0.861622  2.596678
#        3                                    recency_days=mid & store_loyalty_score=high 0.089950    0.860574  2.593520
#        3                         product_diversity_score=mid & store_loyalty_score=high 0.036503    0.856617  2.581596
#        3                          MT_TTC_NET_total_spend=mid & store_loyalty_score=high 0.061711    0.848547  2.557275
#        3                         MT_TTC_NET_total_spend=high & store_loyalty_score=high 0.016241    0.840958  2.534403
#        3                        avg_items_per_basket=high & product_diversity_score=low 0.012327    0.822137  2.477682
#
# Saved: cluster_explain_rules_top.csv

# %%
import numpy as np
import pandas as pd
from itertools import combinations

# =========================
# Extra Block) Re-run ONLY for rule-poor clusters using 2-item antecedents
# with relaxed thresholds (preferred vs jumping to 3-item)
# =========================

# 1) Identify clusters that still have too few explanatory rules after the first pass.
MIN_RULES_PER_CLUSTER = 6
counts = rules_df.groupby("cluster").size().reindex(clusters, fill_value=0)
poor_clusters = counts[counts < MIN_RULES_PER_CLUSTER].index.tolist()

print("Rules per cluster (original 1~2 items):")
print(counts.to_string())
print("\nRule-poor clusters to supplement with relaxed 2-item rules:", poor_clusters)

if len(poor_clusters) == 0:
    print("\nNo supplementation needed.")
else:
    # 2) Re-run two-item mining with relaxed thresholds only for those sparse clusters.
    MIN_SUPPORT_JOINT_2_RELAX = 0.005   # e.g., 0.5% joint support
    MIN_CONFIDENCE_2_RELAX   = 0.40
    MIN_LIFT_2_RELAX         = 1.30

    # Reuse the label-to-bit mapping from the main mining step.
    item_bits = [(it, (np.uint64(1) << np.uint64(i))) for it, i in item_to_bit.items()]
    item_bits = sorted(item_bits, key=lambda x: x[0])

    relaxed_rules = []
    r = 2  # ONLY 2-item antecedents

    for combo in combinations(item_bits, r):
        ant_items = [c[0] for c in combo]
        ant_bits = np.uint64(0)
        for _, b in combo:
            ant_bits |= b

        presence = (bits & ant_bits) == ant_bits
        suppA = presence.mean()

        # Prune rare antecedents early because they cannot satisfy the joint support threshold.
        if suppA < MIN_SUPPORT_JOINT_2_RELAX:
            continue

        # Evaluate only the clusters that need supplemental rules.
        for k in poor_clusters:
            supp_joint = (presence & cluster_masks[k]).mean()
            if supp_joint < MIN_SUPPORT_JOINT_2_RELAX:
                continue

            conf = supp_joint / suppA
            if conf < MIN_CONFIDENCE_2_RELAX:
                continue

            lift = conf / p_cluster[k]
            if lift < MIN_LIFT_2_RELAX:
                continue

            relaxed_rules.append({
                "cluster": k,
                "antecedent": " & ".join(ant_items),
                "consequent": f"cluster={k}",
                "support": supp_joint,
                "confidence": conf,
                "lift": lift,
                "support_antecedent": suppA,
                "antecedent_len": 2
            })

    relaxed_df = pd.DataFrame(relaxed_rules)
    print("\nRelaxed 2-item rules found (only for poor clusters):", len(relaxed_df))

    # 3) Save the supplemental rules separately so the original output remains unchanged.
    relaxed_df.to_csv(GENERATED_DIR / "cluster_rules_2item_relaxed_only_poor_clusters.csv", index=False)
    print("Saved: cluster_rules_2item_relaxed_only_poor_clusters.csv")

    # 4) Build a compact Top-N summary from the supplemental rules.
    TOP_N_PER_CLUSTER = TOP_N_PER_CLUSTER  # reuse your existing variable

    top_relaxed = []
    for k in poor_clusters:
        sub = (relaxed_df[relaxed_df["cluster"] == k]
               .sort_values(["lift", "confidence", "support"], ascending=[False, False, False])
               .head(TOP_N_PER_CLUSTER))
        top_relaxed.append(sub)

    top_relaxed_df = pd.concat(top_relaxed, ignore_index=True) if len(top_relaxed) else relaxed_df
    top_relaxed_df.to_csv(GENERATED_DIR / "cluster_explain_rules_top_2item_relaxed.csv", index=False)
    print("Saved: cluster_explain_rules_top_2item_relaxed.csv")

    # Optional preview
    if len(top_relaxed_df) > 0:
        print("\nPreview (relaxed 2-item top rules for poor clusters):")
        print(top_relaxed_df[["cluster","antecedent","support","confidence","lift"]].to_string(index=False))
# Out:
# Rules per cluster (original 1~2 items):
# cluster
# 0    86
# 1    38
# 2    13
# 3    66
#
# Rule-poor clusters to supplement with relaxed 2-item rules: []
#
# No supplementation needed.

# %%
# # keep clusters 0/1/2 from original result, replace cluster 3 with relaxed rules
# non_poor = [0,1,2]
# merged = pd.concat([
#     result[result["cluster"].isin(non_poor)].copy(),
#     top_relaxed_df.copy()   # 你补跑代码里的 top_relaxed_df
# ], ignore_index=True)

# merged.to_csv(GENERATED_DIR / "cluster_explain_rules_top_final.csv", index=False)

# %%
# # Just added for the cluster 3


# # =========================
# # Extra Block) Re-run ONLY for clusters with few rules (3-item antecedents)
# # (Minimal change: keep the original 1~2-item mining intact)
# # =========================
# import numpy as np
# import pandas as pd
# from itertools import combinations

# # 1) Decide which clusters are "rule-poor"
# MIN_RULES_PER_CLUSTER = 6  # e.g., if a cluster has <6 rules from 1~2 items, we will supplement with 3-item rules

# counts_2 = rules_df.groupby("cluster").size().reindex(clusters, fill_value=0)
# poor_clusters = counts_2[counts_2 < MIN_RULES_PER_CLUSTER].index.tolist()

# print("Rules per cluster (1~2 items):")
# print(counts_2.to_string())
# print("\nRule-poor clusters to supplement:", poor_clusters)

# # If no cluster needs supplementation, skip
# if len(poor_clusters) == 0:
#     print("\nNo supplementation needed.")
# else:
#     # 2) Mine 3-item antecedents only (to avoid duplicating 1~2-item rules)
#     #    Use slightly relaxed thresholds (optional but usually necessary)
#     MIN_SUPPORT_JOINT_3 = 0.005   # joint support(A∧cluster) for 3-item (often needs to be lower)
#     MIN_CONFIDENCE_3   = 0.40
#     MIN_LIFT_3         = 1.30

#     # Prepare item_bits once
#     item_bits = [(it, (np.uint64(1) << np.uint64(i))) for it, i in item_to_bit.items()]
#     item_bits = sorted(item_bits, key=lambda x: x[0])

#     rules_3 = []
#     r = 3  # 3-item only

#     for combo in combinations(item_bits, r):
#         ant_items = [c[0] for c in combo]
#         ant_bits = np.uint64(0)
#         for _, b in combo:
#             ant_bits |= b

#         presence = (bits & ant_bits) == ant_bits
#         suppA = presence.mean()

#         # small pruning: if antecedent itself is rarer than MIN_SUPPORT_JOINT_3, joint support cannot exceed it
#         if suppA < MIN_SUPPORT_JOINT_3:
#             continue

#         # Only compute for the "poor" clusters
#         for k in poor_clusters:
#             supp_joint = (presence & cluster_masks[k]).mean()
#             if supp_joint < MIN_SUPPORT_JOINT_3:
#                 continue

#             conf = supp_joint / suppA
#             if conf < MIN_CONFIDENCE_3:
#                 continue

#             lift = conf / p_cluster[k]
#             if lift < MIN_LIFT_3:
#                 continue

#             rules_3.append({
#                 "cluster": k,
#                 "antecedent": " & ".join(ant_items),
#                 "consequent": f"cluster={k}",
#                 "support": supp_joint,
#                 "confidence": conf,
#                 "lift": lift,
#                 "support_antecedent": suppA,
#                 "antecedent_len": 3
#             })

#     rules_3_df = pd.DataFrame(rules_3)
#     print("\n3-item rules found (only for poor clusters):", len(rules_3_df))

#     # 3) Merge: keep your original rules_df (1~2 items), add 3-item rules only for poor clusters
#     rules_df_aug = rules_df.copy()
#     if "antecedent_len" not in rules_df_aug.columns:
#         rules_df_aug["antecedent_len"] = rules_df_aug["antecedent"].apply(lambda s: str(s).count("&") + 1)

#     if len(rules_3_df) > 0:
#         rules_df_aug = pd.concat([rules_df_aug, rules_3_df], ignore_index=True)

#     # 4) Rebuild "Top-N per cluster" result, but ONLY fill gaps for poor clusters
#     #    - For non-poor clusters: keep the original top rules from result
#     #    - For poor clusters: take best rules from augmented pool (lift -> confidence -> support)
#     TOP_N_PER_CLUSTER = TOP_N_PER_CLUSTER  # reuse your existing variable

#     result_new_parts = []

#     # Keep original for non-poor clusters
#     non_poor = [k for k in clusters if k not in poor_clusters]
#     if len(non_poor) > 0:
#         result_new_parts.append(result[result["cluster"].isin(non_poor)].copy())

#     # Recompute top-N for poor clusters from augmented pool
#     for k in poor_clusters:
#         sub = (rules_df_aug[rules_df_aug["cluster"] == k]
#                .sort_values(["lift", "confidence", "support"], ascending=[False, False, False])
#                .head(TOP_N_PER_CLUSTER)
#                .copy())
#         result_new_parts.append(sub)

#     result_aug = pd.concat(result_new_parts, ignore_index=True)
#     result_aug = result_aug.sort_values(["cluster", "lift", "confidence", "support"], ascending=[True, False, False, False])

#     # 5) Save as a NEW file (do not overwrite your original outputs)
#     result_aug.to_csv(GENERATED_DIR / "cluster_explain_rules_top_augmented.csv", index=False)
#     print("\nSaved: cluster_explain_rules_top_augmented.csv")

#     # Optional: preview
#     print("\nPreview (augmented) top rules per cluster:")
#     print(result_aug[["cluster", "antecedent", "support", "confidence", "lift", "antecedent_len"]]
#           .groupby("cluster")
#           .head(10)
#           .to_string(index=False))

# %%
import pandas as pd

result = pd.read_csv(GENERATED_DIR / "cluster_explain_rules_top.csv")

for k in sorted(result["cluster"].unique()):
    sub = result[result["cluster"] == k].sort_values(
        ["lift", "confidence", "support"], ascending=[False, False, False]
    )
    print("\n" + "="*80)
    print(f"Cluster {k} - top rules")
    print(sub[["antecedent","support","confidence","lift"]].head(10).to_string(index=False))
# Out:
# ================================================================================
# Cluster 0 - top rules
#                                                    antecedent  support  confidence     lift
#                 MT_TTC_NET_total_spend=low & recency_days=low 0.076103    0.942916 2.018567
#                    recency_days=low & store_loyalty_score=mid 0.097133    0.859125 1.839190
#    CD_TICKET_UNIQUE_total_transactions=low & recency_days=low 0.170933    0.842127 1.802801
#                avg_days_between_visits=low & recency_days=low 0.172171    0.838676 1.795413
# ID_MAG_TIERS_stores_visited=high & MT_TTC_NET_total_spend=mid 0.016580    0.830782 1.778514
#                   avg_items_per_basket=low & recency_days=low 0.084426    0.830693 1.778324
#                       avg_basket_value=low & recency_days=low 0.076879    0.828676 1.774005
#                product_diversity_score=mid & recency_days=low 0.089620    0.827602 1.771707
#          MT_TTC_NET_total_spend=low & store_loyalty_score=low 0.016109    0.819748 1.754893
#  ID_MAG_TIERS_stores_visited=mid & MT_TTC_NET_total_spend=low 0.015349    0.817143 1.749316
#
# ================================================================================
# Cluster 1 - top rules
#                                                                  antecedent  support  confidence     lift
#                        avg_basket_value=high & avg_days_between_visits=high 0.062760    0.757373 5.352571
#            CD_TICKET_UNIQUE_total_transactions=high & avg_basket_value=high 0.063693    0.754204 5.330173
#             ID_MAG_TIERS_stores_visited=high & avg_days_between_visits=high 0.048781    0.737026 5.208770
# CD_TICKET_UNIQUE_total_transactions=high & ID_MAG_TIERS_stores_visited=high 0.049136    0.734601 5.191630
#                    avg_days_between_visits=high & avg_items_per_basket=high 0.062042    0.719801 5.087034
#        CD_TICKET_UNIQUE_total_transactions=high & avg_items_per_basket=high 0.062843    0.717342 5.069659
#              ID_MAG_TIERS_stores_visited=high & MT_TTC_NET_total_spend=high 0.068523    0.667605 4.718154
#                         ID_MAG_TIERS_stores_visited=high & recency_days=low 0.036404    0.655808 4.634783
#                ID_MAG_TIERS_stores_visited=high & avg_items_per_basket=high 0.051589    0.642204 4.538634
#         ID_MAG_TIERS_stores_visited=high & QTY_PROMO_NAT_nat_promo_qty=high 0.040359    0.635465 4.491013
#
# ================================================================================
# Cluster 2 - top rules
#                                                                     antecedent  support  confidence      lift
#                       QTY_PROMO_STORE_store_promo_qty=high & recency_days=high 0.033853    0.849917 14.268805
# CD_TICKET_UNIQUE_total_transactions=low & QTY_PROMO_STORE_store_promo_qty=high 0.031384    0.699871 11.749763
#             QTY_PROMO_STORE_store_promo_qty=high & avg_days_between_visits=low 0.031690    0.698962 11.734499
#              MT_TTC_NET_total_spend=mid & QTY_PROMO_STORE_store_promo_qty=high 0.014119    0.652174 10.949000
#         ID_MAG_TIERS_stores_visited=low & QTY_PROMO_STORE_store_promo_qty=high 0.019585    0.626519 10.518289
#             QTY_PROMO_STORE_store_promo_qty=high & product_diversity_score=mid 0.013178    0.616692 10.353320
#                 QTY_PROMO_STORE_store_promo_qty=high & store_loyalty_score=mid 0.014309    0.592276  9.943408
#        QTY_PROMO_NAT_nat_promo_qty=high & QTY_PROMO_STORE_store_promo_qty=high 0.026191    0.550790  9.246921
#                   QTY_PROMO_STORE_store_promo_qty=high & avg_basket_value=high 0.026521    0.513345  8.618276
#         ID_MAG_TIERS_stores_visited=mid & QTY_PROMO_STORE_store_promo_qty=high 0.014697    0.505395  8.484802
#
# ================================================================================
# Cluster 3 - top rules
#                                                          antecedent  support  confidence     lift
#                    avg_basket_value=high & store_loyalty_score=high 0.024259    0.894641 2.696188
#                        recency_days=high & store_loyalty_score=high 0.094285    0.882117 2.658445
#                avg_items_per_basket=high & store_loyalty_score=high 0.033795    0.864597 2.605644
# CD_TICKET_UNIQUE_total_transactions=high & store_loyalty_score=high 0.027644    0.864446 2.605191
#             avg_days_between_visits=high & store_loyalty_score=high 0.026323    0.861622 2.596678
#                         recency_days=mid & store_loyalty_score=high 0.089950    0.860574 2.593520
#              product_diversity_score=mid & store_loyalty_score=high 0.036503    0.856617 2.581596
#               MT_TTC_NET_total_spend=mid & store_loyalty_score=high 0.061711    0.848547 2.557275
#              MT_TTC_NET_total_spend=high & store_loyalty_score=high 0.016241    0.840958 2.534403
#             avg_items_per_basket=high & product_diversity_score=low 0.012327    0.822137 2.477682

# %%
df = pd.read_csv(GENERATED_DIR / "customers_with_segments.csv")

FEATURES = [
    "MT_TTC_NET_total_spend",
    "CD_TICKET_UNIQUE_total_transactions",
    "avg_basket_value",
    "avg_items_per_basket",
    "product_diversity_score",
    "promo_percentage",
    "QTY_PROMO_STORE_store_promo_qty",
    "QTY_PROMO_NAT_nat_promo_qty",
    "ID_MAG_TIERS_stores_visited",
    "store_loyalty_score",
    "recency_days",
    "avg_days_between_visits",
]

for c in FEATURES:
    s = pd.to_numeric(df[c], errors="coerce").dropna()
    q33, q66 = s.quantile([1/3, 2/3]).values
    print(f"{c}: low <= {q33:.4g}, mid in ({q33:.4g}, {q66:.4g}], high > {q66:.4g}")
# Out:
# MT_TTC_NET_total_spend: low <= 16.55, mid in (16.55, 40.23], high > 40.23
# CD_TICKET_UNIQUE_total_transactions: low <= 1, mid in (1, 1], high > 1
# avg_basket_value: low <= 13.61, mid in (13.61, 29.92], high > 29.92
# avg_items_per_basket: low <= 5.401, mid in (5.401, 11.64], high > 11.64
# product_diversity_score: low <= 6, mid in (6, 22], high > 22
# promo_percentage: low <= 0, mid in (0, 0], high > 0
# QTY_PROMO_STORE_store_promo_qty: low <= 0, mid in (0, 0], high > 0
# QTY_PROMO_NAT_nat_promo_qty: low <= 0, mid in (0, 0], high > 0
# ID_MAG_TIERS_stores_visited: low <= 2, mid in (2, 3], high > 3
# store_loyalty_score: low <= 0.3333, mid in (0.3333, 0.5], high > 0.5
# recency_days: low <= 4, mid in (4, 11], high > 11
# avg_days_between_visits: low <= 0, mid in (0, 0], high > 0

# %%
import pandas as pd
import numpy as np

# 1) Load the previously generated rule file.
rules = pd.read_csv(GENERATED_DIR / "cluster_explain_rules_top.csv")

# 2) Approximate the baseline size of each cluster from confidence and lift.
# Since lift = confidence / P(cluster), rearrange to estimate P(cluster).
rules["p_cluster_est"] = rules["confidence"] / rules["lift"]

# 3) Estimate what share of each cluster is captured by each rule.
# Coverage within cluster = support(A and cluster) / P(cluster).
rules["coverage_in_cluster_est"] = rules["support"] / rules["p_cluster_est"]

# 4) Translate technical antecedents into plain-language customer descriptions.
def to_human(row):
    ant = row["antecedent"]

    # In the current binning setup, some features are effectively binary (>0 vs =0)
    ant = ant.replace("promo_percentage=high", "Has promo purchases (>0)")
    ant = ant.replace("promo_percentage=low", "No promo purchases (=0)")
    ant = ant.replace("promo_percentage=mid", "No promo purchases (=0)")

    ant = ant.replace("QTY_PROMO_STORE_store_promo_qty=high", "Has store promo purchases (>0)")
    ant = ant.replace("QTY_PROMO_STORE_store_promo_qty=low", "No store promo purchases (=0)")
    ant = ant.replace("QTY_PROMO_STORE_store_promo_qty=mid", "No store promo purchases (=0)")

    ant = ant.replace("QTY_PROMO_NAT_nat_promo_qty=high", "Has national promo purchases (>0)")
    ant = ant.replace("QTY_PROMO_NAT_nat_promo_qty=low", "No national promo purchases (=0)")
    ant = ant.replace("QTY_PROMO_NAT_nat_promo_qty=mid", "No national promo purchases (=0)")

    ant = ant.replace("CD_TICKET_UNIQUE_total_transactions=high", "Transactions > 1")
    ant = ant.replace("CD_TICKET_UNIQUE_total_transactions=low", "Transactions = 1 (or low)")
    ant = ant.replace("CD_TICKET_UNIQUE_total_transactions=mid", "Transactions = 1 (or low)")

    ant = ant.replace("recency_days=high", "Inactive for a long time (>11 days)")
    ant = ant.replace("recency_days=mid", "Medium recency (5-11 days)")
    ant = ant.replace("recency_days=low", "Recently active (<=4 days)")

    ant = ant.replace("ID_MAG_TIERS_stores_visited=high", "Visited many stores (>3)")
    ant = ant.replace("ID_MAG_TIERS_stores_visited=mid", "Visited a medium number of stores (=3)")
    ant = ant.replace("ID_MAG_TIERS_stores_visited=low", "Visited few stores (<=2)")

    ant = ant.replace("store_loyalty_score=high", "High single-store loyalty (>0.5)")
    ant = ant.replace("store_loyalty_score=mid", "Medium store loyalty (0.333-0.5)")
    ant = ant.replace("store_loyalty_score=low", "Low store loyalty (<=0.333)")

    ant = ant.replace("MT_TTC_NET_total_spend=high", "High total spend")
    ant = ant.replace("MT_TTC_NET_total_spend=mid", "Medium total spend")
    ant = ant.replace("MT_TTC_NET_total_spend=low", "Low total spend")

    ant = ant.replace("avg_basket_value=high", "High average basket value")
    ant = ant.replace("avg_basket_value=mid", "Medium average basket value")
    ant = ant.replace("avg_basket_value=low", "Low average basket value")

    ant = ant.replace("avg_items_per_basket=high", "Large baskets (many items)")
    ant = ant.replace("avg_items_per_basket=mid", "Medium basket size")
    ant = ant.replace("avg_items_per_basket=low", "Small baskets (few items)")

    ant = ant.replace("product_diversity_score=high", "High product diversity")
    ant = ant.replace("product_diversity_score=mid", "Medium product diversity")
    ant = ant.replace("product_diversity_score=low", "Low product diversity")

    ant = ant.replace("avg_days_between_visits=high", "Repeat visits (avg gap > 0)")
    ant = ant.replace("avg_days_between_visits=mid", "Single-day / one-off pattern (avg gap = 0)")
    ant = ant.replace("avg_days_between_visits=low", "Single-day / one-off pattern (avg gap = 0)")

    return ant

rules["business_readable_antecedent"] = rules.apply(to_human, axis=1)

# 5) For each cluster, keep the most representative rules:
# prioritize lift, then coverage within cluster, then confidence
out = []
for k in sorted(rules["cluster"].unique()):
    sub = rules[rules["cluster"] == k].copy()
    sub = sub.sort_values(
        ["lift", "coverage_in_cluster_est", "confidence"],
        ascending=[False, False, False]
    )

    # Approximate baseline share of this cluster (using the first row in the sorted subset)
    sub["cluster_est_size"] = sub["p_cluster_est"].iloc[0]

    out.append(sub.head(10))

report = pd.concat(out, ignore_index=True)

print(report[[
    "cluster",
    "business_readable_antecedent",
    "support",
    "confidence",
    "lift",
    "coverage_in_cluster_est",
    "cluster_est_size"
]].to_string(index=False))

# Save a report-friendly output file
report.to_csv(GENERATED_DIR / "cluster_profile_report.csv", index=False)
print("\nSaved: cluster_profile_report.csv")
# Out:
#  cluster                                                business_readable_antecedent  support  confidence      lift  coverage_in_cluster_est  cluster_est_size
#        0                                Low total spend & Recently active (<=4 days) 0.076103    0.942916  2.018567                 0.162919          0.467121
#        0               Recently active (<=4 days) & Medium store loyalty (0.333-0.5) 0.097133    0.859125  1.839190                 0.207940          0.467121
#        0                      Transactions = 1 (or low) & Recently active (<=4 days) 0.170933    0.842127  1.802801                 0.365928          0.467121
#        0     Single-day / one-off pattern (avg gap = 0) & Recently active (<=4 days) 0.172171    0.838676  1.795413                 0.368579          0.467121
#        0                               Visited many stores (>3) & Medium total spend 0.016580    0.830782  1.778514                 0.035493          0.467121
#        0                      Small baskets (few items) & Recently active (<=4 days) 0.084426    0.830693  1.778324                 0.180737          0.467121
#        0                       Low average basket value & Recently active (<=4 days) 0.076879    0.828676  1.774005                 0.164581          0.467121
#        0                       Medium product diversity & Recently active (<=4 days) 0.089620    0.827602  1.771707                 0.191855          0.467121
#        0                               Low total spend & Low store loyalty (<=0.333) 0.016109    0.819748  1.754893                 0.034486          0.467121
#        0                    Visited a medium number of stores (=3) & Low total spend 0.015349    0.817143  1.749316                 0.032860          0.467121
#        1                     High average basket value & Repeat visits (avg gap > 0) 0.062760    0.757373  5.352571                 0.443543          0.141497
#        1                                Transactions > 1 & High average basket value 0.063693    0.754204  5.330173                 0.450137          0.141497
#        1                      Visited many stores (>3) & Repeat visits (avg gap > 0) 0.048781    0.737026  5.208770                 0.344751          0.141497
#        1                                 Transactions > 1 & Visited many stores (>3) 0.049136    0.734601  5.191630                 0.347260          0.141497
#        1                    Repeat visits (avg gap > 0) & Large baskets (many items) 0.062042    0.719801  5.087034                 0.438466          0.141497
#        1                               Transactions > 1 & Large baskets (many items) 0.062843    0.717342  5.069659                 0.444127          0.141497
#        1                                 Visited many stores (>3) & High total spend 0.068523    0.667605  4.718154                 0.484274          0.141497
#        1                       Visited many stores (>3) & Recently active (<=4 days) 0.036404    0.655808  4.634783                 0.257280          0.141497
#        1                       Visited many stores (>3) & Large baskets (many items) 0.051589    0.642204  4.538634                 0.364591          0.141497
#        1                Visited many stores (>3) & Has national promo purchases (>0) 0.040359    0.635465  4.491013                 0.285231          0.141497
#        2        Has store promo purchases (>0) & Inactive for a long time (>11 days) 0.033853    0.849917 14.268805                 0.568339          0.059565
#        2                  Transactions = 1 (or low) & Has store promo purchases (>0) 0.031384    0.699871 11.749763                 0.526892          0.059565
#        2 Has store promo purchases (>0) & Single-day / one-off pattern (avg gap = 0) 0.031690    0.698962 11.734499                 0.532021          0.059565
#        2                         Medium total spend & Has store promo purchases (>0) 0.014119    0.652174 10.949000                 0.237039          0.059565
#        2                   Visited few stores (<=2) & Has store promo purchases (>0) 0.019585    0.626519 10.518289                 0.328805          0.059565
#        2                   Has store promo purchases (>0) & Medium product diversity 0.013178    0.616692 10.353320                 0.221236          0.059565
#        2           Has store promo purchases (>0) & Medium store loyalty (0.333-0.5) 0.014309    0.592276  9.943408                 0.240227          0.059565
#        2          Has national promo purchases (>0) & Has store promo purchases (>0) 0.026191    0.550790  9.246921                 0.439701          0.059565
#        2                  Has store promo purchases (>0) & High average basket value 0.026521    0.513345  8.618276                 0.445245          0.059565
#        2     Visited a medium number of stores (=3) & Has store promo purchases (>0) 0.014697    0.505395  8.484802                 0.246742          0.059565
#        3                High average basket value & High single-store loyalty (>0.5) 0.024259    0.894641  2.696188                 0.073108          0.331817
#        3      Inactive for a long time (>11 days) & High single-store loyalty (>0.5) 0.094285    0.882117  2.658445                 0.284147          0.331817
#        3               Large baskets (many items) & High single-store loyalty (>0.5) 0.033795    0.864597  2.605644                 0.101849          0.331817
#        3                         Transactions > 1 & High single-store loyalty (>0.5) 0.027644    0.864446  2.605191                 0.083311          0.331817
#        3              Repeat visits (avg gap > 0) & High single-store loyalty (>0.5) 0.026323    0.861622  2.596678                 0.079329          0.331817
#        3               Medium recency (5-11 days) & High single-store loyalty (>0.5) 0.089950    0.860574  2.593520                 0.271083          0.331817
#        3                 Medium product diversity & High single-store loyalty (>0.5) 0.036503    0.856617  2.581596                 0.110011          0.331817
#        3                       Medium total spend & High single-store loyalty (>0.5) 0.061711    0.848547  2.557275                 0.185981          0.331817
#        3                         High total spend & High single-store loyalty (>0.5) 0.016241    0.840958  2.534403                 0.048946          0.331817
#        3                          Large baskets (many items) & Low product diversity 0.012327    0.822137  2.477682                 0.037151          0.331817
#
# Saved: cluster_profile_report.csv

# %%
import glob

files = sorted(glob.glob(str(GENERATED_DIR / "association_rules_segment_*.csv")))
if not files:
    print("Didn't find association_rules_segment_*.csv")
else:
    seg_reports = []
    for f in files:
        seg = int(f.split("_")[-1].split(".")[0])  # cluster id
        df = pd.read_csv(f)

        top = df.sort_values(["lift","confidence","support"], ascending=False).head(10).copy()
        top.insert(0, "cluster", seg)
        top.insert(1, "source_file", f)
        seg_reports.append(top)

    seg_report = pd.concat(seg_reports, ignore_index=True)
    seg_report.to_csv(GENERATED_DIR / "cluster_product_rules_top.csv", index=False)
    print("Saved: cluster_product_rules_top.csv")
    print(seg_report.head(30).to_string(index=False))
# Out:
# Saved: cluster_product_rules_top.csv
#  cluster                                                                                                                 source_file                                        antecedents                                        consequents  antecedent support  consequent support  support  confidence     lift  representativity  leverage  conviction  zhangs_metric  jaccard  certainty  kulczynski
#        0 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_0.csv                       frozenset({'Navet et Rave'})                             frozenset({'Carotte'})            0.036679            0.144176 0.023236    0.633492 4.393878               1.0  0.017948    2.335075       0.801821 0.147419   0.571748    0.397328
#        0 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_0.csv                             frozenset({'Carotte'})                       frozenset({'Navet et Rave'})            0.144176            0.036679 0.023236    0.161165 4.393878               1.0  0.017948    1.148403       0.902534 0.147419   0.129225    0.397328
#        0 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_0.csv                  frozenset({'Agrumes', 'Carotte'})                             frozenset({'Poireau'})            0.084784            0.071465 0.023311    0.274945 3.847263               1.0  0.017252    1.280641       0.808634 0.175351   0.219141    0.300565
#        0 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_0.csv                             frozenset({'Poireau'})                  frozenset({'Agrumes', 'Carotte'})            0.071465            0.084784 0.023311    0.326185 3.847263               1.0  0.017252    1.358261       0.797035 0.175351   0.263765    0.300565
#        0 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_0.csv                  frozenset({'Poireau', 'Agrumes'})                             frozenset({'Carotte'})            0.043619            0.144176 0.023311    0.534419 3.706710               1.0  0.017022    1.838184       0.763523 0.141721   0.455985    0.348051
#        0 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_0.csv                             frozenset({'Carotte'})                  frozenset({'Poireau', 'Agrumes'})            0.144176            0.043619 0.023311    0.161683 3.706710               1.0  0.017022    1.140835       0.853235 0.141721   0.123449    0.348051
#        0 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_0.csv                             frozenset({'Poireau'})                             frozenset({'Carotte'})            0.071465            0.144176 0.035944    0.502964 3.488539               1.0  0.025641    1.721854       0.768250 0.200028   0.419231    0.376136
#        0 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_0.csv                             frozenset({'Carotte'})                             frozenset({'Poireau'})            0.144176            0.071465 0.035944    0.249309 3.488539               1.0  0.025641    1.236906       0.833521 0.200028   0.191531    0.376136
#        0 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_0.csv                                frozenset({'PMCF'})                               frozenset({'Piécé'})            0.108132            0.083862 0.030761    0.284480 3.392245               1.0  0.021693    1.280381       0.790711 0.190789   0.218982    0.325645
#        0 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_0.csv                               frozenset({'Piécé'})                                frozenset({'PMCF'})            0.083862            0.108132 0.030761    0.366810 3.392245               1.0  0.021693    1.408532       0.769764 0.190789   0.290041    0.325645
#        1 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_1.csv              frozenset({'Courgette', 'Condiment'})                   frozenset({'Banane', 'Carotte'})            0.051856            0.081903 0.020070    0.387025 4.725428               1.0  0.015822    1.497772       0.831497 0.176531   0.332342    0.316034
#        1 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_1.csv                   frozenset({'Banane', 'Carotte'})              frozenset({'Courgette', 'Condiment'})            0.081903            0.051856 0.020070    0.245042 4.725428               1.0  0.015822    1.255890       0.858709 0.176531   0.203752    0.316034
#        1 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_1.csv      frozenset({'Banane', 'Condiment', 'Carotte'})                           frozenset({'Courgette'})            0.041763            0.103364 0.020070    0.480556 4.649146               1.0  0.015753    1.726144       0.819116 0.160482   0.420674    0.337360
#        1 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_1.csv                           frozenset({'Courgette'})      frozenset({'Banane', 'Condiment', 'Carotte'})            0.103364            0.041763 0.020070    0.194164 4.649146               1.0  0.015753    1.189121       0.875391 0.160482   0.159043    0.337360
#        1 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_1.csv                  frozenset({'Poireau', 'Agrumes'})                       frozenset({'Navet et Rave'})            0.080278            0.057541 0.020534    0.255780 4.445215               1.0  0.015914    1.266373       0.842689 0.175074   0.210343    0.306318
#        1 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_1.csv                       frozenset({'Navet et Rave'})                  frozenset({'Poireau', 'Agrumes'})            0.057541            0.080278 0.020534    0.356855 4.445215               1.0  0.015914    1.430037       0.822358 0.175074   0.300718    0.306318
#        1 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_1.csv                frozenset({'Courgette', 'Agrumes'})                   frozenset({'Banane', 'Carotte'})            0.080162            0.081903 0.028886    0.360347 4.399708               1.0  0.022321    1.435306       0.840053 0.216899   0.303285    0.356519
#        1 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_1.csv                   frozenset({'Banane', 'Carotte'})                frozenset({'Courgette', 'Agrumes'})            0.081903            0.080162 0.028886    0.352691 4.399708               1.0  0.022321    1.421018       0.841645 0.216899   0.296279    0.356519
#        1 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_1.csv                  frozenset({'Poivron', 'Agrumes'})                 frozenset({'Tomate', 'Condiment'})            0.059281            0.086891 0.022622    0.381605 4.391766               1.0  0.017471    1.476578       0.820969 0.183099   0.322759    0.320976
#        1 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_1.csv                 frozenset({'Tomate', 'Condiment'})                  frozenset({'Poivron', 'Agrumes'})            0.086891            0.059281 0.022622    0.260347 4.391766               1.0  0.017471    1.271839       0.845793 0.183099   0.213737    0.320976
#        2 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_2.csv            frozenset({'Navet et Rave', 'Agrumes'})                  frozenset({'Poireau', 'Carotte'})            0.047126            0.074510 0.020087    0.426230 5.720462               1.0  0.016575    1.612997       0.866000 0.197802   0.380036    0.347907
#        2 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_2.csv                  frozenset({'Poireau', 'Carotte'})            frozenset({'Navet et Rave', 'Agrumes'})            0.074510            0.047126 0.020087    0.269585 5.720462               1.0  0.016575    1.304565       0.891623 0.197802   0.233461    0.347907
#        2 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_2.csv       frozenset({'Poireau', 'Agrumes', 'Carotte'})                       frozenset({'Navet et Rave'})            0.058028            0.063501 0.020087    0.346154 5.451192               1.0  0.016402    1.432293       0.866856 0.198011   0.301819    0.331238
#        2 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_2.csv                       frozenset({'Navet et Rave'})       frozenset({'Poireau', 'Agrumes', 'Carotte'})            0.063501            0.058028 0.020087    0.316323 5.451192               1.0  0.016402    1.377802       0.871921 0.198011   0.274207    0.331238
#        2 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_2.csv                  frozenset({'Poireau', 'Carotte'})                       frozenset({'Navet et Rave'})            0.074510            0.063501 0.025280    0.339286 5.343033               1.0  0.020549    1.417405       0.878281 0.224253   0.294485    0.368697
#        2 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_2.csv                       frozenset({'Navet et Rave'})                  frozenset({'Poireau', 'Carotte'})            0.063501            0.074510 0.025280    0.398107 5.343033               1.0  0.020549    1.537634       0.867956 0.224253   0.349650    0.368697
#        2 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_2.csv            frozenset({'Navet et Rave', 'Carotte'})                  frozenset({'Poireau', 'Agrumes'})            0.044358            0.095347 0.020087    0.452830 4.749264               1.0  0.015857    1.653331       0.826085 0.167922   0.395160    0.331749
#        2 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_2.csv                  frozenset({'Poireau', 'Agrumes'})            frozenset({'Navet et Rave', 'Carotte'})            0.095347            0.044358 0.020087    0.210668 4.749264               1.0  0.015857    1.210698       0.872646 0.167922   0.174030    0.331749
#        2 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_2.csv frozenset({'Navet et Rave', 'Agrumes', 'Carotte'})                             frozenset({'Poireau'})            0.033778            0.127366 0.020087    0.594663 4.668933               1.0  0.015784    2.152862       0.813290 0.142401   0.535502    0.376186
#        2 /Users/ponnimuthukumarasamy/Downloads/Prosol Dataset Complete/Sales-Data-Analysis/generated/association_rules_segment_2.csv                             frozenset({'Poireau'}) frozenset({'Navet et Rave', 'Agrumes', 'Carotte'})            0.127366            0.033778 0.020087    0.157709 4.668933               1.0  0.015784    1.147135       0.900513 0.142401   0.128263    0.376186

# %% [markdown]
# ## Results Summary
#
# - Converted customer metrics into low, medium, and high labels, then mined short association rules that explain membership in each cluster.
# - Ranked the strongest rules per cluster using support, confidence, and lift, with an optional relaxed pass for rule-poor clusters.
# - Printed the numeric bin thresholds and created more business-readable versions of the mined rules for reporting.
# - Main outputs: `generated/cluster_explain_rules_top.csv`, `generated/cluster_rules_2item_relaxed_only_poor_clusters.csv`, and `generated/cluster_product_rules_top.csv` when segment product rule files are available.
